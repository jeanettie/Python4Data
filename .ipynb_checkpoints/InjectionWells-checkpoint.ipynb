# %%
import sqlite3
from sqlalchemy import create_engine 
import re
import requests
import pandas as pd # dataframes
from math import pi
import datetime
from itertools import chain
from collections import namedtuple
from bokeh.io import show, output_notebook
from bokeh.plotting import figure, output_file, show
from bokeh.models import HoverTool, FuncTickFormatter, FixedTicker, ColumnDataSource, SingleIntervalTicker, LinearAxis

# %%
injection_wells = pd.read_csv("data/InjectionWells.csv")

# %%
injection_wells['Approval Date'] = pd.to_datetime(injection_wells['Approval Date'], format='%m/%d/%Y')

# %%
injection_wells.head()
# Out:
#            API#                                Operator  Operator ID WellType  \
# 0  3.500300e+09                   PHOENIX PETROCORP INC      19499.0       2R
# 1  3.500300e+09                CHAMPLIN EXPLORATION INC       4030.0       2R
# 2  3.500321e+09                      LINN OPERATING INC      22182.0       2R
# 3  3.500321e+09  SANDRIDGE EXPLORATION & PRODUCTION LLC      22281.0       2R
# 4  3.500321e+09                CHAMPLIN EXPLORATION INC       4030.0       2R
#
#                    WellName WellNumber  OrderNumbers Approval Date   County  \
# 0  SE EUREKA UNIT-TUCKER #1         21      133856.0    1977-09-06  ALFALFA
# 1               CHRISTENSEN          1      470258.0    2002-11-27  ALFALFA
# 2          NE CHEROKEE UNIT         85      329426.0    1988-08-19  ALFALFA
# 3                     VELMA       2-19      281652.0    1985-07-11  ALFALFA
# 4                      GRAY         1A      470257.0    2002-11-27  ALFALFA
#
#   Sec     ...       Rng         QQQQ        LAT      LONG    PSI   BBLS  \
# 0  13     ...       10W      C-SE SE  36.900324 -98.21826  2,500    300
# 1  21     ...       09W      C-NW NW  36.896636 -98.17772  2,400  1,000
# 2  24     ...       11W        SE NE  36.806113 -98.32584  1,050  1,000
# 3  19     ...       10W  SW NE NE SW  36.888589 -98.31853  3,152  1,000
# 4  20     ...       09W     SE SW NW  36.892128 -98.19462  1,000  2,400
#
#        ZONE Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0  CHEROKEE         NaN          NaN          NaN
# 1  RED FORK         NaN          NaN          NaN
# 2  RED FORK         NaN          NaN          NaN
# 3  RED FORK         NaN          NaN          NaN
# 4  RED FORK         NaN          NaN          NaN
#
# [5 rows x 21 columns]

# %%
#Creating the cursor connections
conn = sqlite3.connect('injection_wells.db')
cur = conn.cursor() 
cursor = conn.cursor()

# %%
#Creating the database Injection_Wells
injection_wells.to_sql("Injection_Wells", conn, if_exists='replace', index=True)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\pandas\core\generic.py:1362: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %%
cur.execute("DROP TABLE Year;")
cur.execute("create table Year as select  WellName,strftime('%Y', `Approval Date`) as approval_year from Injection_Wells;")

#cur.execute("select strftime('%Y',`Approval Date`) from 'Injection_Wells'; ")
#Years=cur.fetchall()
#print(Years)

#cur.executemany('INSERT INTO Injection_Wells(Year) VALUES (?)', Years)
#conn.commit()

# %%
#tesing new table from query

cur.execute("pragma table_info(Year);")
tablecolumnnames=cur.fetchall()
print(tablecolumnnames)
# Out:
# [(0, 'WellName', 'TEXT', 0, None, 0), (1, 'approval_year', '', 0, None, 0)]

# %%
cur.execute("select approval_year, count(approval_year) as year_count from Year group by approval_year;")
year_count=cur.fetchall()
print(year_count)
# Out:
# [(None, 0), ('1936', 1), ('1945', 1), ('1946', 1), ('1947', 4), ('1948', 1), ('1949', 8), ('1950', 13), ('1951', 2), ('1952', 8), ('1953', 34), ('1954', 34), ('1955', 45), ('1956', 64), ('1957', 71), ('1958', 65), ('1959', 179), ('1960', 126), ('1961', 157), ('1962', 134), ('1963', 95), ('1964', 64), ('1965', 96), ('1966', 80), ('1967', 92), ('1968', 276), ('1969', 95), ('1970', 99), ('1971', 145), ('1972', 192), ('1973', 79), ('1974', 77), ('1975', 76), ('1976', 77), ('1977', 79), ('1978', 76), ('1979', 123), ('1980', 142), ('1981', 132), ('1982', 173), ('1983', 242), ('1984', 243), ('1985', 141), ('1986', 182), ('1987', 199), ('1988', 175), ('1989', 159), ('1990', 268), ('1991', 195), ('1992', 254), ('1993', 208), ('1994', 143), ('1995', 190), ('1996', 212), ('1997', 175), ('1998', 177), ('1999', 134), ('2000', 175), ('2001', 153), ('2002', 167), ('2003', 194), ('2004', 170), ('2005', 165), ('2006', 200), ('2007', 275), ('2008', 234), ('2009', 246), ('2010', 293), ('2011', 438), ('2012', 448), ('2013', 403), ('2014', 392), ('2015', 246), ('2016', 217), ('2017', 196)]

# %%
cur.execute("select * from Year")
results=cur.fetchall()
print(results)
# Out:
# [('SE EUREKA UNIT-TUCKER #1', '1977'), ('CHRISTENSEN', '2002'), ('NE CHEROKEE UNIT', '1988'), ('VELMA', '1985'), ('GRAY', '2002'), ('NORTH CARMEN RED FORK UNIT', '1996'), ('LESLIE', '2010'), ('USF&G FELLERS', '1990'), ('BURCHFIEL', '1999'), ('NORTH CARMEN RED FORK UNIT', '1998'), ("MEANS 'C'", '2006'), ('LSB MCCRADY 4', '2006'), ('REITZ', '1994'), ('DORTHY', '1994'), ('MIKE UT#38449', '1994'), ('TULLIS', '1999'), ('KRAFT', '2013'), ('NECU', '2010'), ('BETTY JO', '2007'), ('MILAN', '2012'), ('ALFALFA', '2006'), ('HDW', '2007'), ('SE BRADLEY A UNIT M', '2016'), ('LEAMON', '2016'), ('GIDEON', '2008'), ('LILY SWD', '2010'), ('DUTCH HARBOR SWD', '2016'), ('BAILAR SWD', '2011'), ('RISITA SWD', '2010'), ('DORADO SWD', '2010'), ('FIERO SWD', '2011'), ('TIBURON SWD', '2010'), ('TIBURON SWD', '2011'), ('GATILLO SWD', '2011'), ('AQUARIUS SWD', '2011'), ('ROSE KELLY SWD', '2011'), ('AMAZON SWD', '2011'), ('CLAUDE SWD', '2011'), ('BETTY ELLEN SWD', '2011'), ('CALLIE SWD', '2011'), ('ROXY SWD', '2011'), ('ALLISON SWD', '2011'), ('NILE 14-28-12 SWD', '2014'), ('OWEN SWD', '2011'), ('CARA SWD', '2011'), ('BAILEY SWD', '2011'), ('SHARON SWD', '2011'), ('FIERO SWD', '2011'), ('JUDY SW
# 1  3.500300e+09                CHAMPLIN EXPLORATION INC       4030.0       2R
# 2  3.500321e+09                      LINN OPERATING INC      22182.0       2R
# 3  3.500321e+09  SANDRIDGE EXPLORATION & PRODUCTION LLC      22281.0       2R
# 4  3.500321e+09                CHAMPLIN EXPLORATION INC       4030.0       2R
#
#                    WellName WellNumber  OrderNumbers Approval Date   County  \
# 0  SE EUREKA UNIT-TUCKER #1         21      133856.0    1977-09-06  ALFALFA
# 1               CHRISTENSEN          1      470258.0    2002-11-27  ALFALFA
# 2          NE CHEROKEE UNIT         85      329426.0    1988-08-19  ALFALFA
# 3                     VELMA       2-19      281652.0    1985-07-11  ALFALFA
# 4                      GRAY         1A      470257.0    2002-11-27  ALFALFA
#
#   Sec     ...       Rng         QQQQ        LAT      LONG    PSI   BBLS  \
# 0  13     ...       10W      C-SE SE  36.900324 -98.21826  2,500    300
# 1  21     ...       09W      C-NW NW  36.896636 -98.17772  2,400  1,000
# 2  24     ...       11W        SE NE  36.806113 -98.32584  1,050  1,000
# 3  19     ...       10W  SW NE NE SW  36.888589 -98.31853  3,152  1,000
# 4  20     ...       09W     SE SW NW  36.892128 -98.19462  1,000  2,400
#
#        ZONE Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0  CHEROKEE         NaN          NaN          NaN
# 1  RED FORK         NaN          NaN          NaN
# 2  RED FORK         NaN          NaN          NaN
# 3  RED FORK         NaN          NaN          NaN
# 4  RED FORK         NaN          NaN          NaN
#
# [5 rows x 21 columns]

# %%
cur.execute("setDataType(`Approval Date`, 'DateTime');")

# %%
injection_wells.dtypes
# Out:
# API#                    float64
# Operator                 object
# Operator ID             float64
# WellType                 object
# WellName                 object
# WellNumber               object
# OrderNumbers            float64
# Approval Date    datetime64[ns]
# County                   object
# Sec                      object
# Twp                      object
# Rng                      object
# QQQQ                     object
# LAT                     float64
# LONG                    float64
# PSI                      object
# BBLS                     object
# ZONE                     object
# Unnamed: 18             float64
# Unnamed: 19             float64
# Unnamed: 20             float64
# dtype: object

# %%
df = pd.DataFrame(year_count)
df.columns = ['Year', 'Count']

df.head()
# Out:
#    Year  Count
# 0  None      0
# 1  1936      1
# 2  1945      1
# 3  1946      1
# 4  1947      4

# %%
count = [row[1] for row in year_count]
year = [row[0] for row in year_count]

output_notebook()


p = figure(plot_width=1200, plot_height=600, x_axis_type=None, y_axis_type=None)

p.line(x=year, y=count, color='navy', alpha=1.5)

p.y_range.start = 0
p.x_range.start = 1936
p.x_range.end = 2018

xticker = SingleIntervalTicker(interval=2, num_minor_ticks=2)
xaxis = LinearAxis(ticker=xticker)
p.add_layout(xaxis, 'below')
p.xaxis.major_label_orientation = "vertical"

yticker = SingleIntervalTicker(interval=20, num_minor_ticks=2)
yaxis = LinearAxis(ticker=yticker)
p.add_layout(yaxis, 'left')

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c1f3cc6e-8cb9-4738-b59b-0e72b16defe7">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="80f7b20a-434c-4baa-a777-ded1866cd0b9"></div>
# </div>
